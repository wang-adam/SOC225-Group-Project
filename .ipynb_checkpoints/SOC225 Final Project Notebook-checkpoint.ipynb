# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations

# %%
data = pd.read_csv("data_raw.csv", sep=";")
data_readable = pd.read_csv("data_readable.csv", sep=",")

# %% [markdown]
# ## Viewing Dataset

# %%
data
# Out:
#      student_id  age  sex  graduated_h_school_type  scholarship_type  \
# 0      STUDENT1    2    2                        3                 3
# 1      STUDENT2    2    2                        3                 3
# 2      STUDENT3    2    2                        2                 3
# 3      STUDENT4    1    1                        1                 3
# 4      STUDENT5    2    2                        1                 3
# ..          ...  ...  ...                      ...               ...
# 140  STUDENT141    2    1                        2                 3
# 141  STUDENT142    1    1                        2                 4
# 142  STUDENT143    1    1                        1                 4
# 143  STUDENT144    2    1                        2                 4
# 144  STUDENT145    1    1                        1                 5
#
#      additional_work  activity  partner  total_salary  transport  ...  \
# 0                  1         2        2             1          1  ...
# 1                  1         2        2             1          1  ...
# 2                  2         2        2             2          4  ...
# 3                  1         2        1             2          1  ...
# 4                  2         2        1             3          1  ...
# ..               ...       ...      ...           ...        ...  ...
# 140                1         1        2             1          1  ...
# 141                2         2        2             1          4  ...
# 142                2         2        2             1          1  ...
# 143                1         1        1             5          2  ...
# 144                2         2        2             3          1  ...
#
#      preparation_midterm_company  preparation_midterm_time  taking_notes  \
# 0                              1                         1             3
# 1                              1                         1             3
# 2                              1                         1             2
# 3                              1                         2             3
# 4                              2                         1             2
# ..                           ...                       ...           ...
# 140                            1                         1             2
# 141                            1                         1             3
# 142                            1                         1             3
# 143                            2                         1             2
# 144                            2                         1             3
#
#      listenning  discussion_improves_interest  flip_classrom  grade_previous  \
# 0             2                             1              2               1
# 1             2                             3              2               2
# 2             2                             1              1               2
# 3             2                             2              1               3
# 4             2                             2              1               2
# ..          ...                           ...            ...             ...
# 140           1                             2              1               3
# 141           2                             2              1               5
# 142           3                             2              1               4
# 143           1                             2              1               5
# 144           2                             3              1               5
#
#      grade_expected  course_id  grade
# 0                 1          1      1
# 1                 3          1      1
# 2                 2          1      1
# 3                 2          1      1
# 4                 2          1      1
# ..              ...        ...    ...
# 140               3          9      5
# 141               3          9      5
# 142               3          9      1
# 143               3          9      4
# 144               4          9      3
#
# [145 rows x 33 columns]

# %%
data_readable
# Out:
#      student_id    age     sex graduated_h_school_type scholarship_type  \
# 0      STUDENT1  22-25    male                   other              50%
# 1      STUDENT2  22-25    male                   other              50%
# 2      STUDENT3  22-25    male                   state              50%
# 3      STUDENT4  18-21  female                 private              50%
# 4      STUDENT5  22-25    male                 private              50%
# ..          ...    ...     ...                     ...              ...
# 140  STUDENT141  22-25  female                   state              50%
# 141  STUDENT142  18-21  female                   state              75%
# 142  STUDENT143  18-21  female                 private              75%
# 143  STUDENT144  22-25  female                   state              75%
# 144  STUDENT145  18-21  female                 private             100%
#
#     additional_work activity  partner total_salary         transport  ...  \
# 0               Yes        No      No      135-200               Bus  ...
# 1               Yes        No      No      135-200               Bus  ...
# 2                No        No      No      201-270             Other  ...
# 3               Yes        No     Yes      201-270               Bus  ...
# 4                No        No     Yes      271-340               Bus  ...
# ..              ...       ...     ...          ...               ...  ...
# 140             Yes       Yes      No      135-200               Bus  ...
# 141              No        No      No      135-200             Other  ...
# 142              No        No      No      135-200               Bus  ...
# 143             Yes       Yes     Yes    Above 410  Private car/taxi  ...
# 144              No        No      No      271-340               Bus  ...
#
#     preparation_midterm_company   preparation_midterm_time taking_notes  \
# 0                         Alone              Close to Exam       Always
# 1                         Alone              Close to Exam       Always
# 2                         Alone              Close to Exam    Sometimes
# 3                         Alone  Regularly during Semester       Always
# 4                  With Friends              Close to Exam    Sometimes
# ..                          ...                        ...          ...
# 140                       Alone              Close to Exam    Sometimes
# 141                       Alone              Close to Exam       Always
# 142                       Alone              Close to Exam       Always
# 143                With Friends              Close to Exam    Sometimes
# 144                With Friends              Close to Exam       Always
#
#      listening discussion_improves_interest flip_classrom grade_previous  \
# 0    Sometimes                        Never        Useful          <2.00
# 1    Sometimes                       Always        Useful      2.00-2.49
# 2    Sometimes                        Never    Not Useful      2.00-2.49
# 3    Sometimes                    Sometimes    Not Useful      2.50-2.99
# 4    Sometimes                    Sometimes    Not Useful      2.00-2.49
# ..         ...                          ...           ...            ...
# 140      Never                    Sometimes    Not Useful      2.50-2.99
# 141  Sometimes                    Sometimes    Not Useful     Above 3.49
# 142     Always                    Sometimes    Not Useful      3.00-3.49
# 143      Never                    Sometimes    Not Useful     Above 3.49
# 144  Sometimes                       Always    Not Useful     Above 3.49
#
#     grade_expected course_id grade
# 0            <2.00         1    DD
# 1        2.50-2.99         1    DD
# 2        2.00-2.49         1    DD
# 3        2.00-2.49         1    DD
# 4        2.00-2.49         1    DD
# ..             ...       ...   ...
# 140      2.50-2.99         9    BB
# 141      2.50-2.99         9    BB
# 142      2.50-2.99         9    DD
# 143      2.50-2.99         9    CB
# 144      3.00-3.49         9    CC
#
# [145 rows x 33 columns]

# %% [markdown]
# ## Visualizing Features to Grade

# %% [markdown]
# ### Weekly Study Hours to GPA by Course

# %%
grades = []
study_hours = []
plot_num = 1
prev_course = 1
for index, row in data_readable.iterrows():
    ax = plt.subplot(3, 3, plot_num)
    g = row['grade_previous']
    s = row['weekly_study_hours']
    course = row['course_id']
    if course != prev_course:
        ax.scatter(study_hours, grades)
        ax.set_xlabel('Number of Study Hours')
        ax.set_ylabel('Grade')
        ax.set_title('Course ' + str(prev_course))
        plt.tick_params(axis='both', which='major', labelsize=5)
        plot_num +=1
        grades.clear()
        study_hours.clear()
    prev_course = row['course_id']
    grades.append(g)
    study_hours.append(s)
ax.scatter(study_hours, grades)
ax.set_xlabel('Number of Study Hours')
ax.set_ylabel('Grade')
ax.set_title('Course ' + str(prev_course))
plot_num +=1
grades.clear()
study_hours.clear()
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=5)

# %% [markdown]
# ## Running Linear Regression on DataSet

# %% [markdown]
# ### data preparation

# %%
# Creating X matrix
X = data.drop(columns=['grade_expected', 'grade', 'student_id'])
# Creating y matrix
y = data['grade_expected']
y = np.array(y)
# Turning x into array
X = X.to_numpy()
# Transpose X and y
X = X.T
y = y.T
print(X.shape)
print(y.shape)
# Out:
# (30, 145)
# (145,)

# %% [markdown]
# ### finding the best predictor

# %%
for i in range(30):
    plt.subplot(1,2,2-(i+1)%2)
    X_ = np.vstack([X[i], np.ones(len(X[i]))]).T
    w1, w0 = np.linalg.lstsq(X_, y, rcond=None)[0]
    t = np.linspace(np.min(X[i]),np.max(X[i]),20)
    plt.plot(X[i],y,'.')
    plt.plot(t, w1*t + w0, 'r')
    plt.title(data.columns[i])
    if ((i+1)%2==0):
        plt.show()

# %% [markdown]
# ### the best linear predictor using all 30 features

# %%
A = np.vstack([X, np.ones(len(X[i]))]).T
w=np.zeros(11)
w = np.linalg.lstsq(A, y, rcond=None)[0]
Y_=np.matmul(A,w)
plt.plot(y,Y_,'.')
plt.plot([-130, 200],[-130, 200],'k-')
plt.show()
